# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanasajeer/github/blob/main/carcrashes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('/content/drive/MyDrive/car_crashes.csv')

# %%
data
# Out:
#     total  speeding  alcohol  ...  ins_premium  ins_losses  abbrev
# 0    18.8     7.332    5.640  ...       784.55      145.08      AL
# 1    18.1     7.421    4.525  ...      1053.48      133.93      AK
# 2    18.6     6.510    5.208  ...       899.47      110.35      AZ
# 3    22.4     4.032    5.824  ...       827.34      142.39      AR
# 4    12.0     4.200    3.360  ...       878.41      165.63      CA
# 5    13.6     5.032    3.808  ...       835.50      139.91      CO
# 6    10.8     4.968    3.888  ...      1068.73      167.02      CT
# 7    16.2     6.156    4.860  ...      1137.87      151.48      DE
# 8     5.9     2.006    1.593  ...      1273.89      136.05      DC
# 9    17.9     3.759    5.191  ...      1160.13      144.18      FL
# 10   15.6     2.964    3.900  ...       913.15      142.80      GA
# 11   17.5     9.450    7.175  ...       861.18      120.92      HI
# 12   15.3     5.508    4.437  ...       641.96       82.75      ID
# ...

# %%
data.head()
# Out:
#    total  speeding  alcohol  ...  ins_premium  ins_losses  abbrev
# 0   18.8     7.332    5.640  ...       784.55      145.08      AL
# 1   18.1     7.421    4.525  ...      1053.48      133.93      AK
# 2   18.6     6.510    5.208  ...       899.47      110.35      AZ
# 3   22.4     4.032    5.824  ...       827.34      142.39      AR
# 4   12.0     4.200    3.360  ...       878.41      165.63      CA
#
# [5 rows x 8 columns]

# %%
data.shape
# Out:
# (51, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
data.isna().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
data.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
data.abbrev.nunique()
# Out:
# 51

# %%
data.drop(['abbrev'],axis=1)
# Out:
#     total  speeding  alcohol  ...  no_previous  ins_premium  ins_losses
# 0    18.8     7.332    5.640  ...       15.040       784.55      145.08
# 1    18.1     7.421    4.525  ...       17.014      1053.48      133.93
# 2    18.6     6.510    5.208  ...       17.856       899.47      110.35
# 3    22.4     4.032    5.824  ...       21.280       827.34      142.39
# 4    12.0     4.200    3.360  ...       10.680       878.41      165.63
# 5    13.6     5.032    3.808  ...       12.920       835.50      139.91
# 6    10.8     4.968    3.888  ...        8.856      1068.73      167.02
# 7    16.2     6.156    4.860  ...       16.038      1137.87      151.48
# 8     5.9     2.006    1.593  ...        5.900      1273.89      136.05
# 9    17.9     3.759    5.191  ...       16.826      1160.13      144.18
# 10   15.6     2.964    3.900  ...       14.508       913.15      142.80
# 11   17.5     9.450    7.175  ...       15.225       861.18      120.92
# ...

# %%
dgraph=data.select_dtypes(include=['float'])
dgraph.hist(figsize=(20,15))
plt.show()

# %%
data.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
data.groupby('total')['speeding'].mean()
# Out:
# total
# 5.9     2.0060
# 8.2     1.8860
# 9.6     2.2080
# 10.6    4.4520
# 10.8    4.9680
# 11.1    3.7740
# 11.2    1.7920
# 11.3    4.8590
# 11.6    4.0600
# 12.0    4.2000
# 12.3    3.9360
# 12.5    4.2500
# 12.7    2.4130
# 12.8    4.4160
# 13.6    4.5560
# 13.8    4.9680
# 14.1    3.6660
# 14.5    3.6250
# 14.7    5.4390
# 14.9    1.9370
# 15.1    5.7380
# 15.3    5.5080
# 15.6    2.9640
# 15.7    2.6690
# 16.1    6.9230
# 16.2    6.1560
# 16.8    6.5520
# 17.4    7.3080
# 17.5    9.4500
# 17.6    2.6400
# 17.8    4.8060
# 17.9    3.7590
# 18.1    7.4210
# 18.2    9.1000
# 18.4    3.4960
# 18.6    6.5100
# 18.8    7.3320
# 19.4    6.8870
# 19.5    4.0950
# 19.9    6.3680
# 20.5    7.1750
# 21.4    6.2060
# 22.4    4.0320
# 23.8    8.0920
# 23.9    7.2895
# Name: speeding, dtype: float64

# %%
# outliers in alcohol

plt.boxplot(data['alcohol'])
plt.title('boxplot of alcohol')
# Out:
# Text(0.5, 1.0, 'boxplot of alcohol')

# %%
q1=np.percentile(data['alcohol'],25,interpolation='midpoint')
q2=np.percentile(data['alcohol'],50,interpolation='midpoint')
q3=np.percentile(data['alcohol'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 3.894
# 4.553999999999999
# 5.603999999999999

# %%
data['alcohol'].median()
# Out:
# 4.553999999999999

# %%
iqr=q3-q1
low_limit = q1-1.5*iqr
up_limit=q3+1.5*iqr
print(low_limit)
print(up_limit)
# Out:
# 1.3290000000000015
# 8.168999999999997

# %%
outlier=[]
for x in data['alcohol']:
  if((x>up_limit) or (x<low_limit)):
    outlier.append(x)
outlier
# Out:
# [9.416, 10.038, 9.799]

# %%
# find index of outliers

ind1 = data['alcohol']>up_limit
data.loc[ind1].index
# Out:
# Int64Index([26, 34, 40], dtype='int64')

# %%
# drp these index
data.drop([26, 34, 40], inplace=True)

# %%
plt.boxplot(data['alcohol'])
plt.title('boxplot of alcohol')
# Out:
# Text(0.5, 1.0, 'boxplot of alcohol')

# %%
# ouliers in ins_losses
plt.boxplot(data['ins_losses'])
plt.title('boxplot of ins_losses')
# Out:
# Text(0.5, 1.0, 'boxplot of ins_losses')

# %%
# outliers in ins_premium
plt.boxplot(data['ins_premium'])
plt.title('boxplot of ins_premium')
# Out:
# Text(0.5, 1.0, 'boxplot of ins_premium')

# %%
plt.boxplot(data['no_previous'])
plt.title('boxplot of no previous')
# Out:
# Text(0.5, 1.0, 'boxplot of no previous')

# %%
# otlier in
plt.boxplot(data['not_distracted'])
plt.title('boxplot of not distracted')
# Out:
# Text(0.5, 1.0, 'boxplot of not distracted')

# %%
# outlier
plt.boxplot(data['speeding'])
plt.title('boxplot of speeding')
# Out:
# Text(0.5, 1.0, 'boxplot of speeding')

# %%
# outlier
plt.boxplot(data['total'])
plt.title('boxplot of total')
# Out:
# Text(0.5, 1.0, 'boxplot of total')

# %%
data.shape
# Out:
# (48, 8)

# %%
data=data.drop(['abbrev'],axis=1)

# %%
corrmatrix = data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix, vmin=0.4, vmax=0.9, annot=True, linewidths=0.2, cmap='YlGnBu')

# %%
y=data['total']
x=data.drop(['total'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=42, test_size=0.2)
# create linear model
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
prediction=model.predict(x_test)

# %%
# check the mse
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,prediction))
# Out:
# MSE is: 0.8276239707690205

# %%
# r2 ed value
from sklearn.metrics import r2_score
print('R squared value is:',r2_score(y_test,prediction))
# Out:
# R squared value is: 0.8545706354409636

# %%
x.describe()
# Out:
#         speeding    alcohol  ...  ins_premium  ins_losses
# count  48.000000  48.000000  ...    48.000000   48.000000
# mean    4.832979   4.582771  ...   893.143958  136.416458
# std     1.924760   1.253760  ...   181.164464   24.093693
# min     1.792000   1.593000  ...   641.960000   82.750000
# 25%     3.725500   3.868000  ...   768.690000  118.862500
# 50%     4.351000   4.527500  ...   865.515000  137.920000
# 75%     6.209000   5.460500  ...  1015.822500  152.335000
# max     9.450000   7.372000  ...  1301.520000  194.780000
#
# [8 rows x 6 columns]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn import preprocessing
standards=preprocessing.StandardScaler()
x=standards.fit_transform(x)

# %%
x=pd.DataFrame(x)
x.describe()
# Out:
#                   0             1  ...             4             5
# count  4.800000e+01  4.800000e+01  ...  4.800000e+01  4.800000e+01
# mean  -1.804112e-16 -4.903485e-16  ... -6.707597e-16 -1.457168e-16
# std    1.010582e+00  1.010582e+00  ...  1.010582e+00  1.010582e+00
# min   -1.596646e+00 -2.409878e+00  ... -1.401169e+00 -2.250978e+00
# 25%   -5.814746e-01 -5.761347e-01  ... -6.942364e-01 -7.362806e-01
# 50%   -2.530600e-01 -4.455057e-02  ... -1.541215e-01  6.306433e-02
# 75%    7.224706e-01  7.074858e-01  ...  6.843327e-01  6.676850e-01
# max    2.424136e+00  2.248233e+00  ...  2.278027e+00  2.447992e+00
#
# [8 rows x 6 columns]

# %%
x=data.drop(['total'],axis=1)
x.describe()
# Out:
#         speeding    alcohol  ...  ins_premium  ins_losses
# count  48.000000  48.000000  ...    48.000000   48.000000
# mean    4.832979   4.582771  ...   893.143958  136.416458
# std     1.924760   1.253760  ...   181.164464   24.093693
# min     1.792000   1.593000  ...   641.960000   82.750000
# 25%     3.725500   3.868000  ...   768.690000  118.862500
# 50%     4.351000   4.527500  ...   865.515000  137.920000
# 75%     6.209000   5.460500  ...  1015.822500  152.335000
# max     9.450000   7.372000  ...  1301.520000  194.780000
#
# [8 rows x 6 columns]

# %%
min_max=preprocessing.MinMaxScaler(feature_range=(0,1))
x=min_max.fit_transform(x)

# %%
x=pd.DataFrame(x)
x.describe()
# Out:
#                0          1          2          3          4          5
# count  48.000000  48.000000  48.000000  48.000000  48.000000  48.000000
# mean    0.397098   0.517351   0.530623   0.505183   0.380836   0.479036
# std     0.251340   0.216951   0.192940   0.235039   0.274675   0.215065
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.252481   0.393667   0.394917   0.337858   0.192143   0.322347
# 50%     0.334160   0.507787   0.561779   0.502828   0.338946   0.492457
# 75%     0.576782   0.669233   0.652068   0.662841   0.566836   0.621128
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=42, test_size=0.2)
# create linear model
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
prediction=model.predict(x_test)
# check the mse
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,prediction))
# Out:
# MSE is: 0.8276239707690223

# %%
from sklearn.metrics import r2_score
print('R squared value is:',r2_score(y_test,prediction))
# Out:
# R squared value is: 0.8545706354409632

# %%
x=data.drop(['total'],axis=1)
x.describe()
# Out:
#         speeding    alcohol  ...  ins_premium  ins_losses
# count  48.000000  48.000000  ...    48.000000   48.000000
# mean    4.832979   4.582771  ...   893.143958  136.416458
# std     1.924760   1.253760  ...   181.164464   24.093693
# min     1.792000   1.593000  ...   641.960000   82.750000
# 25%     3.725500   3.868000  ...   768.690000  118.862500
# 50%     4.351000   4.527500  ...   865.515000  137.920000
# 75%     6.209000   5.460500  ...  1015.822500  152.335000
# max     9.450000   7.372000  ...  1301.520000  194.780000
#
# [8 rows x 6 columns]

# %%
x=preprocessing.normalize(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                0          1          2          3          4          5
# count  48.000000  48.000000  48.000000  48.000000  48.000000  48.000000
# mean    0.005551   0.005276   0.015089   0.015735   0.987634   0.153103
# std     0.002359   0.001716   0.005613   0.004831   0.003722   0.023245
# min     0.001367   0.001243   0.001935   0.004605   0.979571   0.106192
# 25%     0.003799   0.004050   0.011335   0.013142   0.985057   0.133325
# 50%     0.005297   0.005482   0.015047   0.016431   0.987886   0.153280
# 75%     0.007215   0.006752   0.019043   0.019115   0.990896   0.169793
# max     0.010863   0.009459   0.028090   0.025331   0.994322   0.198757

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=42, test_size=0.2)
# create linear model
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
prediction=model.predict(x_test)
# check the mse
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,prediction))
# Out:
# MSE is: 6.45161177854109

# %%
from sklearn.metrics import r2_score
print('R squared value is:',r2_score(y_test,prediction))
# Out:
# R squared value is: -0.13367161231810254

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=0.4,vmax=0.9,annot=True,linewidth=0.2,cmap='YlGnBu')

# %%
data.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses'],
#       dtype='object')

# %%
data.drop(['alcohol', 'not_distracted'],axis=1,inplace=True)

# %%
y=data['total']
x=data.drop(['total'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=42, test_size=0.2)
# create linear model
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
prediction=model.predict(x_test)
# check the mse
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,prediction))
# Out:
# MSE is: 0.9063599039058771

# %%
from sklearn.metrics import r2_score
print('R squared value is:',r2_score(y_test,prediction))
# Out:
# R squared value is: 0.8407352257277624
